# %%
import math
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def Delta(u_find, u):
	return abs(u_find - u)

a = 1
tuple = np.linspace(start = -a, stop = a, num = a * 10)
exp_x, exp = [], []

for x in tuple:
	sum, term, i = 1.0, 1.0, 1.0
	
	exp.append(math.exp(x))
	while term != 0:
		term_prev, term = term, term * x / i
		sum += term
		i+= 1

	if term_prev < 0 and x < 0:
		sum = sum - term_prev

	exp_x.append(sum)

plt.plot(tuple, exp_x)
plt.grid(True)
plt.xlabel(r'$x$')
plt.ylabel(r'$\exp(x)$')
a = [Delta(exp_x[i], exp[i]) for i in range(len(exp))]
plt.title(r'Exponent, maximum of Delta %s'%(max(a)))
print('Maximum of delta ',max(a))
# Out:
# Maximum of delta  4.440892098500626e-16
